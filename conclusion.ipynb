# %%
# Crear un dataframe con los datos de MSE, RMSE, MAE y R2 de varios modelos, entre ellos regresión lineal

import pandas as pd
import numpy as np

df_train = pd.DataFrame({
    'Modelo': ['Bagging', 'Random Forests', 'AdaBoost', 'Gradient Boosting', 'XGBoost', 'Stacking', 'Linear Regression', 'MLP'],
    'MSE': [0.00058, 0.017919, 0.008677, 0.003192, 0.003192, 0.002874, 0.005665, 0.005569],
    'RMSE': [0.02409, 0.035018, 0.093149, 0.056498, 0.056498, 0.053609, 0.075272, 0.074628],
    'R2': [0.990365, 0.97964, 0.854794, 0.946582, 0.946582, 0.920356, 0.905182, 0.906797],
    'MAE': [0.011934, 0.001226, 0.079243, 0.030974, 0.030974, 0.037100, 0.044437, 0.044768]
})

df_test = pd.DataFrame({
    'Modelo': ['Bagging', 'Random Forests', 'AdaBoost', 'Gradient Boosting', 'XGBoost', 'Stacking', 'Linear Regression', 'MLP'],
    'MSE': [0.003941, 0.030822, 0.009104, 0.004205, 0.004205, 0.004490, 0.005830, 0.005757],
    'RMSE': [0.062777, 0.060926, 0.095413, 0.064844, 0.064844, 0.067005, 0.076357, 0.075873],
    'R2': [0.933332, 0.933332, 0.850736, 0.931057, 0.931057, 0.920356, 0.900440, 0.905609],
    'MAE': [0.030988, 0.003712, 0.080483, 0.035405, 0.035405, 0.037100, 0.046122, 0.046575]
})

# %%
# Mostrar un gráfico comparativo

import matplotlib.pyplot as plt

df_train.plot(x='Modelo', y=['MSE', 'RMSE', 'MAE'], kind='bar')
plt.title('Errores en entrenamiento')
plt.ylabel('Error')
plt.show()

# %%
# Mostrar un gráfico comparativo

import matplotlib.pyplot as plt

df_test.plot(x='Modelo', y=['MSE', 'RMSE', 'MAE'], kind='bar')
plt.title('Errores en test')
plt.ylabel('Error')
plt.show()

# %%
# Mostrar ahora un gráfico comparativo de R2

df_train.plot(x='Modelo', y='R2', kind='bar')
plt.title('R2 en entrenamiento')

df_test.plot(x='Modelo', y='R2', kind='bar')
plt.title('R2 en test')

plt.show()
